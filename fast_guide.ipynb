# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## 1 Mask on image

# %%
from utils import *
from mask_image import *
from mask_video import *

# %%
source_image = cv2.imread("olya_1.jpg") # put your selfie here
MASK_NAME = '2_new_year_hat.PNG' # choose mask file (it should be located in 'masks' dir)

result = mask_image(source_image, MASK_NAME)
result = cv2.cvtColor(result, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(10, 10))
plt.imshow(result)
plt.show()

# %%
source_image = cv2.imread("olya_3.jpg") # put your selfie here
MASK_NAME = 'mask2.jpg' # choose mask file (it should be located in 'masks' dir)

result = mask_image(source_image, MASK_NAME)
result = cv2.cvtColor(result, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(10, 10))
plt.imshow(result)
plt.show()

# %% [markdown]
# ## 2 Mask on video
#
# #### Angel / devil

# %%
source_video = 'drive/My Drive/Computer Vision/Project/videos/masha.mp4' # put your video here
output_video = 'drive/My Drive/Computer Vision/Project/videos/masha_out.mp4' # put your file name here
mask_video_angel_devil(source_video, output_video, show_frames=True, rotate=True)

# %% [markdown]
# #### Simple mask (that does not depend on movement)

# %%
source_video = 'drive/My Drive/Computer Vision/Project/videos/masha.mp4' # put your video here
output_video = 'drive/My Drive/Computer Vision/Project/videos/masha_out_simple.mp4' # put your file name here
mask_video_simple(source_video, output_video, '2_new_year_hat.PNG', show_frames=False, rotate=True)

# %% [markdown]
# #### Mask with mouth opening

# %%
source_video = 'drive/My Drive/Computer Vision/Project/videos/masha2.mp4' # put your video here
output_video = 'drive/My Drive/Computer Vision/Project/videos/masha2_out_corona_mask.mp4' # put your file name here
mask_video_simple(source_video, output_video, '2_new_year_hat.PNG', add_corona_mask=True, show_frames=True, rotate=True)
